# %% [markdown]
# <a href="https://colab.research.google.com/github/coryroyce/code_assignments/blob/main/211024_Hierarchical_Clustering(Agglomerative)_Single_Link_Cory_Randolph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hierarchical Clustering(Agglomerative) Single Link Assignment
# Cory Randolph
#
# 10/24/2021
#
# CMPE 256

# %% [markdown]
# # Prompt

# %% [markdown]
# Given data points provided, develop Hierarchical Clustering(Agglomerative) using Single Link technique?
#
# Learning Objective: Apply Single Link Hierarchical Clustering(Agglomerative) :
#
# Hierarchical algorithms can be further divided into divisive algorithms and agglomerative algorithms. Divisive clustering begins with all data elements in one cluster, which is later successively divided into smaller ones. On the other hand, agglomerative clustering begins with single-element clusters and works by successively merging them into larger ones.
#
# Part B: please develop Cluster Python  program and run single-link, Complete-link and average-link Clusters and upload code and screen captures.

# %% [markdown]
# Data Points:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Data
# Define the data points to be used

# %%
data = [
               [2,2],
               [2,6,],
               [3,7],
               [5,2],
               [5,5],
               [5,8],
               [6,6],
               [7,3],
               [8,4],
               [10,6],
               [12,8],
]

# %% [markdown]
# Convert the data points into a Pandas Dataframe

# %%
df = pd.DataFrame(data, columns = ['X', 'Y'])

# %% [markdown]
# Plot the points to verify

# %%
df.plot.scatter(x = 'X', y = 'Y')

# %% [markdown]
# # Single Link Clustering

# %% [markdown]
# Use the scipy library for clusering and dendrogram visualization

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform
from scipy.spatial import distance_matrix

# %% [markdown]
# Calcualte the distance matrix

# %%
dist_matrix = distance_matrix(data, data)

# %% [markdown]
# Visualize as pandas dataframe

# %%
pd.DataFrame(dist_matrix)
# Out:
#            0          1         2   ...        8         9          10
# 0    0.000000   4.000000  5.099020  ...  6.324555  8.944272  11.661904
# 1    4.000000   0.000000  1.414214  ...  6.324555  8.000000  10.198039
# 2    5.099020   1.414214  0.000000  ...  5.830952  7.071068   9.055385
# 3    3.000000   5.000000  5.385165  ...  3.605551  6.403124   9.219544
# 4    4.242641   3.162278  2.828427  ...  3.162278  5.099020   7.615773
# 5    6.708204   3.605551  2.236068  ...  5.000000  5.385165   7.000000
# 6    5.656854   4.000000  3.162278  ...  2.828427  4.000000   6.324555
# 7    5.099020   5.830952  5.656854  ...  1.414214  4.242641   7.071068
# 8    6.324555   6.324555  5.830952  ...  0.000000  2.828427   5.656854
# 9    8.944272   8.000000  7.071068  ...  2.828427  0.000000   2.828427
# 10  11.661904  10.198039  9.055385  ...  5.656854  2.828427   0.000000
#
# [11 rows x 11 columns]

# %% [markdown]
# Apply square form to remove the 0's and symetric duplicates

# %%
distances = squareform(dist_matrix)

# %% [markdown]
# Create a single linked cluster

# %%
linkage_single = linkage(distances, 'single')

# %% [markdown]
# Create a dendogram to visualize

# %%
# Define labeled points
point_labels = [f'({point[0]},{point[1]})' for point in data]

dendrogram(linkage_single, labels = point_labels)
# Label the dendrogram
plt.title('Single Link')
plt.show()

# %%
# Define labeled points
point_labels = [f'({point[0]},{point[1]})' for point in data]

dendrogram(linkage_single, labels = point_labels)
# Label the dendrogram
plt.title('Single Link')
plt.show()

# %% [markdown]
# # Complete Link Cluster

# %% [markdown]
# Since the data, distance and labels are all the same we just need to update the last few lines of code to get the other types of linkages.

# %% [markdown]
# Create an Complete linked cluster

# %%
linkage_complete = linkage(distances, 'complete')

# %% [markdown]
# Create a dendogram to visualize

# %%
# Define labeled points
point_labels = [f'({point[0]},{point[1]})' for point in data]

dendrogram(linkage_complete, labels = point_labels)
# Label the dendrogram
plt.title('Complete Link')
plt.show()

# %% [markdown]
# # Average Link Cluster

# %% [markdown]
# Since the data, distance and labels are all the same we just need to update the last few lines of code to get the other types of linkages.

# %% [markdown]
# Create an average linked cluster

# %%
linkage_average = linkage(distances, 'average')

# %% [markdown]
# Create a dendogram to visualize

# %%
# Define labeled points
point_labels = [f'({point[0]},{point[1]})' for point in data]

dendrogram(linkage_average, labels = point_labels)
# Label the dendrogram
plt.title('Average Link')
plt.show()
